# %% [markdown]
# # Chapter 2: Accessing Text Corpora and Lexical Resources

# %% [markdown]
# ### Useful Definitions
# __corpora__ - large bodies of linguistic data
# __stylistics__ - a linguistic inquiry into the characteristics of a particular text or collection of texts
# __conditional frequency distribution__ - a collection of frequency distributions, each for a different condition
# __lexical entry__ - a block consisting of a headword (lemma), additional information, and a sense definition
# __lemma__ - the canonical form of a word
# __stopwords__ - high frequency words often omitted from lexical inquiries due to overrepresentation in most texts and thus irrelevance to most inquiries
# __synset__ - synonym set; a collection of synonymous lemmas
# __unique beginners (*root synsets*)__ - generic terms representing the root of a WordNet hierarchy
# __hyponyms__ - words associated by direct descendance with a particular word in a concept hierarchy for example *motorcar -> ambulance*
# __hypernyms__ - word(s) that serves as the conceptual ancestor to a particular word in a concept hierarchy
# __meronyms__ - the components that serve to make up the particular concept; e.g. word = tree is comprised of trunk, crown, limbs, stump, etc.
# __holonyms__ - the set that the particular word falls under conceptually; e.g. tree is a sub-component of a forest
# __entail__ - term used in describing relationships between verbs; e.g. walking *entails* stepping

# %%
from nltk.corpus import gutenberg
#gutenberg.fileids()
macbeth_sentences = gutenberg.sents('shakespeare-macbeth.txt')
longest_len = max([len(s) for s in macbeth_sentences])
print(longest_len)
[s for s in macbeth_sentences if len(s) == longest_len]
# Out:
# 158
# [['Doubtfull',
#   'it',
#   'stood',
#   ',',
#   'As',
#   'two',
#   'spent',
#   'Swimmers',
#   ',',
#   'that',
#   'doe',
#   'cling',
#   'together',
#   ',',
#   'And',
#   'choake',
#   'their',
#   'Art',
#   ':',
#   'The',
#   'mercilesse',
#   'Macdonwald',
#   '(',
#   'Worthie',
#   'to',
#   'be',
#   'a',
#   'Rebell',
#   ',',
#   'for',
#   'to',
#   'that',
#   'The',
#   'multiplying',
#   'Villanies',
#   'of',
#   'Nature',
#   'Doe',
#   'swarme',
#   'vpon',
#   'him',
#   ')',
#   'from',
#   'the',
#   'Westerne',
#   'Isles',
#   'Of',
#   'Kernes',
#   'and',
#   'Gallowgrosses',
#   'is',
#   'supply',
#   "'",
#   'd',
#   ',',
#   'And',
#   'Fortune',
#   'on',
#   'his',
#   'damned',
#   'Quarry',
#   'smiling',
#   ',',
#   'Shew',
#   "'",
#   'd',
#   'like',
#   'a',
#   'Rebells',
#   'Whore',
#   ':',
#   'but',
#   'all',
#   "'",
#   's',
#   'too',
#   'weake',
#   ':',
#   'For',
#   'braue',
#   'Macbeth',
#   '(',
#   'well',
# ...
